# %%
# !pip install pandas
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 891.5 kB/s eta 0:00:12
#    -- ------------------------------------- 0.8/11.0 MB 1.0 MB/s eta 0:00:11
#    --- ------------------------------------ 1.0/11.0 MB 943.9 kB/s eta 0:00:11
#    ---- ----------------------------------- 1.3/11.0 MB 975.7 kB/s eta 0:00:10
#    ----- ---------------------------------- 1.6/11.0 MB 1.0 MB/s eta 0:00:10
#    ------ --------------------------------- 1.8/11.0 MB 1.1 MB/s eta 0:00:09
#    ------- -------------------------------- 2.1/11.0 MB 1.1 MB/s eta 0:00:09
# ...

# %%
# !pip install psycopg2-binary

# %%
import pandas as pd

# %%
import psycopg2

# Database connect
conn = psycopg2.connect(
    dbname="hr_agent",
    user="postgres",
    password="hussaindb",  # apna actual password daalo
    host="localhost",
    port="5432"
)
cur = conn.cursor()


cur.execute("""
    INSERT INTO employees (id, name, department, leave_balance)
    VALUES (%s, %s, %s, %s)
""", (54, "Anas", "Web", 6))

conn.commit()  # ✅ save changes
print("Employee added successfully")

cur.close()
conn.close()
# Out:
# Employee added successfully

# %%
import psycopg2
print("✅ psycopg2 installed successfully")

# %%
import pandas as pd
import psycopg2

conn = psycopg2.connect(
    dbname="hr_agent",
    user="postgres",
    password="hussaindb",
    host="localhost",
    port="5432"
)
 
df = pd.read_sql("SELECT * FROM employees;", conn)
display(df)   # Jupyter notebook me table format me show hoga

conn.close()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11556\309830771.py:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM employees;", conn)
#      id      name department  leave_balance leave_history
# 0     1       Ali         IT             10            []
# 1     2      Sara         HR              5            []
# 2     3     Ahmed    Finance              8            []
# 3   104     Ahmed    Finance             12            []
# 4    14    Sajeel         IT             12            []
# 5    11     akash         IT              2            []
# 6     7      ayan         AI              8            []
# 7     9     Ikram         AI              8            []
# 8    10  Mudassar         AI              6            []
# 9    15     Usama    Finance              6            []
# ...

# %%
print(row)
# Out:
# (104, 'Finance', 12)
